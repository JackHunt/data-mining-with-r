# %% [raw]
# ---
# title: "Chapter 2 - Predicting Algae Blooms"
# title-block-banner: true
# number-sections: true
# format:
#   html:
#     toc: true
#     toc-location: left
#     smooth-scroll: true
#     df-print: kable
#     tbl-print: kable
# theme:
#   dark: superhero
#   light: flatly
# ---

# %% [markdown]
# # Setup

# %%
library(DMwR)
library(knitr)
library(ggplot2)
library(ggthemes)
library(patchwork)

# %% [markdown]
# # Data Description
# ## Overview
# The data contain the following variables
#
# * Season in which the measurements were collected.
# * River size.
# * River speed.
# * Max pH value.
# * Min oxygen level.
# * Mean over three measurements
#   * Chloride.
#   * Nitrates.
#   * Ammonium.
#   * Orthophosphate.
#   * Phosphate.
#   * Chlorophyll.
#
# Associated with each are seven frequencies of harmful algae, per water sample.

# %% [markdown]
# ## Summary

# %% [markdown]
# ### Head

# %%
head(algae)
# Out:
#   season size  speed  mxPH mnO2 Cl     NO3    NH4     oPO4    PO4     Chla a1
# 1 winter small medium 8.00  9.8 60.800  6.238 578.000 105.000 170.000 50.0  0.0
# 2 spring small medium 8.35  8.0 57.750  1.288 370.000 428.750 558.750  1.3  1.4
# 3 autumn small medium 8.10 11.4 40.020  5.330 346.667 125.667 187.057 15.6  3.3
# 4 spring small medium 8.07  4.8 77.364  2.302  98.182  61.182 138.700  1.4  3.1
# 5 autumn small medium 8.06  9.0 55.350 10.416 233.700  58.222  97.580 10.5  9.2
# 6 winter small high   8.25 13.1 65.750  9.248 430.000  18.250  56.667 28.4 15.1
#   a2   a3   a4  a5   a6   a7
# 1  0.0  0.0 0.0 34.2  8.3 0.0
# 2  7.6  4.8 1.9  6.7  0.0 2.1
# 3 53.6  1.9 0.0  0.0  0.0 9.7
# 4 41.0 18.9 0.0  1.4  0.0 1.4
# 5  2.9  7.5 0.0  7.5  4.1 1.0
# 6 14.6  1.4 0.0 22.5 12.6 2.9

# %% [markdown]
# ### Summary Stats

# %%
kable(summary(algae))
# Out:
# |   |   season |    size  |   speed  |     mxPH     |     mnO2      |      Cl        |     NO3       |     NH4         |     oPO4      |     PO4       |     Chla       |      a1      |      a2       |      a3       |      a4       |      a5       |      a6       |      a7       |
# |:--|:---------|:---------|:---------|:-------------|:--------------|:---------------|:--------------|:----------------|:--------------|:--------------|:---------------|:-------------|:--------------|:--------------|:--------------|:--------------|:--------------|:--------------|
# |   |autumn:40 |large :45 |high  :84 |Min.   :5.600 |Min.   : 1.500 |Min.   :  0.222 |Min.   : 0.050 |Min.   :    5.00 |Min.   :  1.00 |Min.   :  1.00 |Min.   :  0.200 |Min.   : 0.00 |Min.   : 0.000 |Min.   : 0.000 |Min.   : 0.000 |Min.   : 0.000 |Min.   : 0.000 |Min.   : 0.000 |
# |   |spring:53 |medium:84 |low   :33 |1st Qu.:7.700 |1st Qu.: 7.725 |1st Qu.: 10.981 |1st Qu.: 1.296 |1st Qu.:   38.33 |1st Qu.: 15.70 |1st Qu.: 41.38 |1st Qu.:  2.000 |1st Qu.: 1.50 |1st Qu.: 0.000 |1st Qu.: 0.000 |1st Qu.: 0.000 |1st Qu.: 0.000 |1st Qu.: 0.000 |1st Qu.: 0.000 |
# |   |summer:45 |small :71 |medium:83 |Median :8.060 |Median : 9.800 |Median : 32.730 |Median : 2.675 |Median :  103.17 |Median : 40.15 |Median :103.29 |Median :  5.475 |Median : 6.95 |Median : 3.000 |Median : 1.550 |Median : 0.000 |Median : 1.900 |Median : 0.000 |Median : 1.000 |
# |   |winter:62 |NA        |NA        |Mean   :8.012 |Mean   : 9.118 |Mean   : 43.636 |Mean   : 3.282 |Mean   :  501.30 |Mean   : 73.59 |Mean   :137.88 |Mean   : 13.971 |Mean   :16.92 |Mean   : 7.458 |Mean   : 4.309 |Mean   : 1.992 |Mean   : 5.064 |Mean   : 5.964 |Mean   : 2.495 |
# |   |NA        |NA        |NA        |3rd Qu.:8.400 |3rd Qu.:10.800 |3rd Qu.: 57.824 |3rd Qu.: 4.446 |3rd Qu.:  226.95 |3rd Qu.: 99.33 |3rd Qu.:213.75 |3rd Qu.: 18.308 |3rd Qu.:24.80 |3rd Qu.:11.375 |3rd Qu.: 4.925 |3rd Qu.: 2.400 |3rd Qu.: 7.500 |3rd Qu.: 6.925 |3rd Qu.: 2.400 |
# |   |NA        |NA        |NA        |Max.   :9.700 |Max.   :13.400 |Max.   :391.500 |Max.   :45.650 |Max.   :24064.00 |Max.   :564.60 |Max.   :771.60 |Max.   :110.456 |Max.   :89.80 |Max.   :72.600 |Max.   :42.800 |Max.   :44.600 |Max.   :44.400 |Max.   :77.600 |Max.   :31.600 |
# |   |NA        |NA        |NA        |NA's   :1     |NA's   :2      |NA's   :10      |NA's   :2      |NA's   :2        |NA's   :2      |NA's   :2      |NA's   :12      |NA            |NA             |NA             |NA             |NA             |NA             |NA             |

# %% [markdown]
# ## Variable Distributions

# %%
plot_variable <- function(var) {
    hist <- ggplot(algae, aes(x = {{ var }})) +
        geom_density() +
        theme_economist()

    qq <- ggplot(algae, aes(sample = {{ var }})) +
        stat_qq() +
        stat_qq_line() +
        theme_economist()

    hist + qq + plot_annotation(
        title = paste0("Distribution for ", deparse(substitute(var)))
    )
}

# %% [markdown]
# ### Max pH

# %%
#| warning: false
plot_variable(mxPH)
# Out:
# Warning message:
# "Removed 1 row containing non-finite outside the scale range (`stat_density()`)."
# Warning message:
# "Removed 1 row containing non-finite outside the scale range (`stat_qq()`)."
# Warning message:
# "Removed 1 row containing non-finite outside the scale range (`stat_qq_line()`)."
# plot without title

# %% [markdown]
# ### Min Oxygen

# %%
#| warning: false
plot_variable(mnO2)
# Out:
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range
# (`stat_density()`)."
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range (`stat_qq()`)."
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range
# (`stat_qq_line()`)."
# plot without title

# %% [markdown]
# ### Mean Chloride

# %%
#| warning: false
plot_variable(Cl)
# Out:
# Warning message:
# "Removed 10 rows containing non-finite outside the scale range
# (`stat_density()`)."
# Warning message:
# "Removed 10 rows containing non-finite outside the scale range (`stat_qq()`)."
# Warning message:
# "Removed 10 rows containing non-finite outside the scale range
# (`stat_qq_line()`)."
# plot without title

# %% [markdown]
# ### Mean Nitrates

# %%
#| warning: false
plot_variable(NO3)
# Out:
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range
# (`stat_density()`)."
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range (`stat_qq()`)."
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range
# (`stat_qq_line()`)."
# plot without title

# %% [markdown]
# ### Mean Ammonium

# %%
#| warning: false
plot_variable(NH4)
# Out:
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range
# (`stat_density()`)."
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range (`stat_qq()`)."
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range
# (`stat_qq_line()`)."
# plot without title

# %% [markdown]
# ### Mean Orthophosphate

# %%
#| warning: false
plot_variable(oPO4)
# Out:
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range
# (`stat_density()`)."
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range (`stat_qq()`)."
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range
# (`stat_qq_line()`)."
# plot without title

# %% [markdown]
# ### Mean Phosphate

# %%
#| warning: false
plot_variable(PO4)
# Out:
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range
# (`stat_density()`)."
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range (`stat_qq()`)."
# Warning message:
# "Removed 2 rows containing non-finite outside the scale range
# (`stat_qq_line()`)."
# plot without title

# %% [markdown]
# ### Mean Chlorophyll

# %%
#| warning: false
plot_variable(Chla)
# Out:
# Warning message:
# "Removed 12 rows containing non-finite outside the scale range
# (`stat_density()`)."
# Warning message:
# "Removed 12 rows containing non-finite outside the scale range (`stat_qq()`)."
# Warning message:
# "Removed 12 rows containing non-finite outside the scale range
# (`stat_qq_line()`)."
# plot without title
